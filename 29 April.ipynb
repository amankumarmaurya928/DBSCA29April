# %%
# Q1
'''Clustering analysis is broadly used in many applications such as market research, pattern recognition, data analysis, and
   image processing. Clustering can also help marketers discover distinct groups in their customer base. And they can 
   characterize their customer groups based on the purchasing patterns.
   Clustering technique is used in various applications such as market research and customer segmentation, biological data and
   medical imaging, search result clustering, recommendation engine, pattern recognition, social network analysis, image
   processing, etc.
'''
# Out:
# 'Clustering analysis is broadly used in many applications such as market research, pattern recognition, data analysis, and\n   image processing. Clustering can also help marketers discover distinct groups in their customer base. And they can \n   characterize their customer groups based on the purchasing patterns.\n   Clustering technique is used in various applications such as market research and customer segmentation, biological data and\n   medical imaging, search result clustering, recommendation engine, pattern recognition, social network analysis, image\n   processing, etc.\n'

# %%
# Q2
'''DBSCAN can identify clusters in a large spatial dataset by looking at the local density of corresponding elements. The
   advantage of the DBSCAN algorithm over the K-Means algorithm, is that the DBSCAN can determine which data points are noise 
   or outliers.
   K-means needs a prototype-based concept of a cluster. DBSCAN needs a density-based concept. K-means has difficulty with 
   non-globular clusters and clusters of multiple sizes. DBSCAN is used to handle clusters of multiple sizes and structures 
   and is not powerfully influenced by noise or outliers.
   DBSCAN stands for density-based spatial clustering of applications with noise. It is able to find arbitrary shaped clusters
   and clusters with noise (i.e. outliers). The main idea behind DBSCAN is that a point belongs to a cluster if it is close to
   many points from that cluster.
'''
# Out:
# 'DBSCAN can identify clusters in a large spatial dataset by looking at the local density of corresponding elements. The\n   advantage of the DBSCAN algorithm over the K-Means algorithm, is that the DBSCAN can determine which data points are noise \n   or outliers.\n   K-means needs a prototype-based concept of a cluster. DBSCAN needs a density-based concept. K-means has difficulty with \n   non-globular clusters and clusters of multiple sizes. DBSCAN is used to handle clusters of multiple sizes and structures \n   and is not powerfully influenced by noise or outliers.\n   DBSCAN stands for density-based spatial clustering of applications with noise. It is able to find arbitrary shaped clusters\n   and clusters with noise (i.e. outliers). The main idea behind DBSCAN is that a point belongs to a cluster if it is close to\n   many points from that cluster.\n'

# %%
# Q3
'''The optimal value for epsilon will be found at the point of maximum curvature. We train our model, selecting 0.3 for eps
   and setting min_samples to 5. The labels_ property contains the list of clusters and their respective points. Then, we map
   every individual cluster to a color.
   MinPts: The larger the data set, the larger the value of minPts should be chosen. minPts must be chosen at least 3. ϵ:
   The value for ϵ can then be chosen by using a k-distance graph, plotting the distance to the k = minPts nearest neighbor.
'''
# Out:
# 'The optimal value for epsilon will be found at the point of maximum curvature. We train our model, selecting 0.3 for eps\n   and setting min_samples to 5. The labels_ property contains the list of clusters and their respective points. Then, we map\n   every individual cluster to a color.\n   MinPts: The larger the data set, the larger the value of minPts should be chosen. minPts must be chosen at least 3. ϵ:\n   The value for ϵ can then be chosen by using a k-distance graph, plotting the distance to the k = minPts nearest neighbor.\n'

# %%
# Q4
'''Here SK-Learn library DBSCAN comes to the rescue to allow us to handle outliers for the Multi-variate datasets. DBSCAN 
   considers two main parameters (as mentioned below) to form a cluster with the nearest data point and based on the high or 
   low-density region, it detects Inliers or outliers.
   To find the outliers, find the points that have a negative silhouette coefficient, and remove it. Points lying on the 
   cluster boundaries away from its cluster center can also be removed to create a robust model, but it depends on the 
   case study.
'''
# Out:
# 'Here SK-Learn library DBSCAN comes to the rescue to allow us to handle outliers for the Multi-variate datasets. DBSCAN \n   considers two main parameters (as mentioned below) to form a cluster with the nearest data point and based on the high or \n   low-density region, it detects Inliers or outliers.\n   To find the outliers, find the points that have a negative silhouette coefficient, and remove it. Points lying on the \n   cluster boundaries away from its cluster center can also be removed to create a robust model, but it depends on the \n   case study.\n'

# %%
# Q5
'''K-Means	                                            DBSCAN
K-means generally clusters all the objects.            	DBSCAN discards objects that it defines as noise.
K-means needs a prototype-based concept of a cluster.	DBSCAN needs a density-based concept.
K-means has difficulty with non-globular clusters and
clusters of multiple sizes.                          	DBSCAN is used to handle clusters of multiple sizes and structures and
                                                         is not powerfully influenced by noise or outliers.
K-means can be used for data that has a clear centroid,
including a mean or median.                           	DBSCAN needed that its definition of density, which depends on the
                                                         traditional Euclidean concept of density, be significant for the data.
K-means can be used to sparse, high dimensional data,
including file data.                                 	DBSCAN generally implements poorly for such information because the 
                                                        traditional Euclidean definition of density does not operate well for 
                                                        high dimensional data.
The basic K-means algorithm is similar to a
statistical clustering approach (mixture models) that
consider all clusters come from spherical Gaussian
distributions with several means but the equal 
covariance matrix.                                     	DIISCAN creates no assumption about the distribution of the record.

'''
# Out:
# 'K-Means\t                                            DBSCAN\nK-means generally clusters all the objects.            \tDBSCAN discards objects that it defines as noise.\nK-means needs a prototype-based concept of a cluster.\tDBSCAN needs a density-based concept.\nK-means has difficulty with non-globular clusters and\nclusters of multiple sizes.                          \tDBSCAN is used to handle clusters of multiple sizes and structures and\n                                                         is not powerfully influenced by noise or outliers.\nK-means can be used for data that has a clear centroid,\nincluding a mean or median.                           \tDBSCAN needed that its definition of density, which depends on the\n                                                         traditional Euclidean concept of density, be significant for the data.\nK-means can be used to sparse, high dimensional data,\nincluding file data.                                 \tDBSCAN generally implem
# ...

# %%
# Q6
'''DBSCAN is a typically used clustering algorithm due to its clustering ability for arbitrarily-shaped clusters and its
   robustness to outliers. Generally, the complexity of DBSCAN is O(n^2) in the worst case, and it practically becomes more 
   severe in higher dimension.
   Graph-based clustering (Spectral, SNN-cliq, Seurat) is perhaps most robust for high-dimensional data as it uses the 
   distance on a graph, e.g. the number of shared neighbors, which is more meaningful in high dimensions compared to the
   Euclidean distance.
   Four problems need to be overcome for clustering in high-dimensional data: Multiple dimensions are hard to think in, 
   impossible to visualize, and, due to the exponential growth of the number of possible values with each dimension, complete
   enumeration of all subspaces becomes intractable with increasing dimensionality.
'''
# Out:
# 'DBSCAN is a typically used clustering algorithm due to its clustering ability for arbitrarily-shaped clusters and its\n   robustness to outliers. Generally, the complexity of DBSCAN is O(n^2) in the worst case, and it practically becomes more \n   severe in higher dimension.\n   Graph-based clustering (Spectral, SNN-cliq, Seurat) is perhaps most robust for high-dimensional data as it uses the \n   distance on a graph, e.g. the number of shared neighbors, which is more meaningful in high dimensions compared to the\n   Euclidean distance.\n   Four problems need to be overcome for clustering in high-dimensional data: Multiple dimensions are hard to think in, \n   impossible to visualize, and, due to the exponential growth of the number of possible values with each dimension, complete\n   enumeration of all subspaces becomes intractable with increasing dimensionality.\n'

# %%
# Q7
'''DBSCAN is a density-based clustering algorithm that works on the assumption that clusters are dense regions in space
   separated by regions of lower density. It groups 'densely grouped' data points into a single cluster.
   DBSCAN can find clusters of arbitrary shapes, but it cannot handle data containing clusters of varying densities.
   The DBSCAN algorithm is a prevalent method of density-based clustering algorithms, the most important feature of 
   which is the ability to detect arbitrary shapes and varied clusters and noise data.
'''
# Out:
# "DBSCAN is a density-based clustering algorithm that works on the assumption that clusters are dense regions in space\n   separated by regions of lower density. It groups 'densely grouped' data points into a single cluster.\n   DBSCAN can find clusters of arbitrary shapes, but it cannot handle data containing clusters of varying densities.\n   The DBSCAN algorithm is a prevalent method of density-based clustering algorithms, the most important feature of \n   which is the ability to detect arbitrary shapes and varied clusters and noise data.\n"

# %%
# Q8
'''DBSCAN Parameters
   DBSCAN has two parameters. The first is ε, epsilon (“esp”), which defines the maximum distance allowed between two points
   within the same cluster. The second is minimum samples (“MinPts”), which defines the minimum number of data points required
   to form a distinct cluster.
   Silhouette Method: This technique measures the separability between clusters. First, an average distance is found between
   each point and all other points in a cluster. Then it measures the distance between each point and each point in other 
   clusters.
'''
# Out:
# 'DBSCAN Parameters\n   DBSCAN has two parameters. The first is ε, epsilon (“esp”), which defines the maximum distance allowed between two points\n   within the same cluster. The second is minimum samples (“MinPts”), which defines the minimum number of data points required\n   to form a distinct cluster.\n   Silhouette Method: This technique measures the separability between clusters. First, an average distance is found between\n   each point and all other points in a cluster. Then it measures the distance between each point and each point in other \n   clusters.\n'

# %%
# Q9
'''Clustering methods that can be applied to partially labeled data or data with other types of outcome measures are known as 
   semi-supervised clustering methods (or sometimes as supervised clustering methods).
   Semi-Supervised learning is a type of Machine Learning algorithm that represents the intermediate ground between Supervised
   and Unsupervised learning algorithms. It uses the combination of labeled and unlabeled datasets during the training period.
   Density-based spatial clustering of applications with noise (DBSCAN) is an unsupervised clustering ML algorithm.
   Unsupervised in the sense that it does not use pre-labeled targets to cluster the data points. 
   Clustering in the sense that it attempts to group similar data points into artificial groups or clusters.
'''
# Out:
# 'Clustering methods that can be applied to partially labeled data or data with other types of outcome measures are known as \n   semi-supervised clustering methods (or sometimes as supervised clustering methods).\n   Semi-Supervised learning is a type of Machine Learning algorithm that represents the intermediate ground between Supervised\n   and Unsupervised learning algorithms. It uses the combination of labeled and unlabeled datasets during the training period.\n   Density-based spatial clustering of applications with noise (DBSCAN) is an unsupervised clustering ML algorithm.\n   Unsupervised in the sense that it does not use pre-labeled targets to cluster the data points. \n   Clustering in the sense that it attempts to group similar data points into artificial groups or clusters.\n'

# %%
# Q10
'''DBSCAN stands for density-based spatial clustering of applications with noise. It is able to find arbitrary shaped clusters
   and clusters with noise (i.e. outliers). The main idea behind DBSCAN is that a point belongs to a cluster if it is close to
   many points from that cluster.
   If the issue is due to the presence of null values in road_id, you can first impute the missing values and then apply
   dbscan. For dealing with the missing values, you can either delete the row with missing road_id , but this will result in 
   loss of data.
'''
# Out:
# 'DBSCAN stands for density-based spatial clustering of applications with noise. It is able to find arbitrary shaped clusters\n   and clusters with noise (i.e. outliers). The main idea behind DBSCAN is that a point belongs to a cluster if it is close to\n   many points from that cluster.\n   If the issue is due to the presence of null values in road_id, you can first impute the missing values and then apply\n   dbscan. For dealing with the missing values, you can either delete the row with missing road_id , but this will result in \n   loss of data.\n'

# %%
# Q11
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
# %matplotlib inline
X,y=make_moons(n_samples=250,noise=0.10)

plt.scatter(X[:,0],X[:,1],c=y)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_scaled=scaler.fit_transform(X)

# %%
dbcan=DBSCAN(eps=0.5)

# %%
dbcan.fit(X_scaled)
# Out:
# DBSCAN()

# %%
plt.scatter(X[:,0],X[:,1],c=dbcan.labels_)

# %%
plt.scatter(X[:,0],X[:,1],c=y)
